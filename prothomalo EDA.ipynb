# %%
import pandas as pd
import json
from pathlib import Path

path = Path("prothomalo_articles.jsonl")
rows = []

# Try UTF-8 first, then fallback to latin-1 if needed
with open(path, "r", encoding="utf-8", errors="replace") as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        try:
            rows.append(json.loads(line))
        except Exception:
            pass

df = pd.DataFrame(rows)

# Normalize list-like fields (tags)
if "tags" in df.columns:
    df["tags"] = df["tags"].apply(lambda x: x if isinstance(x, list) else ([] if pd.isna(x) else [x]))

print("\n--- BASIC INFO ---")
print(df.info())
print("\n--- SAMPLE ROWS ---")
print(df.sample(min(5, len(df))))

print("\n--- MISSING VALUES PER COLUMN ---")
print(df.isna().sum())

if "url" in df.columns:
    print("\n--- DUPLICATE URL COUNT ---", df["url"].duplicated().sum())

if "published_iso" in df.columns:
    df["published_dt"] = pd.to_datetime(df["published_iso"], errors="coerce")
    print("\n--- DATE RANGE ---")
    print(df["published_dt"].min(), "to", df["published_dt"].max())
    print("\n--- ARTICLES PER YEAR ---")
    print(df["published_dt"].dt.year.value_counts().sort_index())

if "section" in df.columns:
    print("\n--- TOP SECTIONS ---")
    print(df["section"].value_counts().head(20))

if "author" in df.columns:
    print("\n--- TOP AUTHORS ---")
    print(df["author"].value_counts().head(20))

if "word_count" in df.columns:
    print("\n--- WORD COUNT STATS ---")
    print(df["word_count"].describe())
    print("\n--- TOP LONGEST ARTICLES ---")
    print(df.nlargest(5, "word_count")[["url", "title", "word_count"]])

if "tags" in df.columns:
    tag_counts = pd.Series([t for sub in df["tags"] for t in sub]).value_counts()
    print("\n--- TOP TAGS ---")
    print(tag_counts.head(20))
    print(f"\nTotal unique tags: {tag_counts.shape[0]}")

if "published_dt" in df.columns:
    print("\n--- ARTICLES PER MONTH ---")
    print(df.groupby(df["published_dt"].dt.to_period("M")).size().sort_index())
# Out:
# --- BASIC INFO ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206762 entries, 0 to 206761
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   url             206762 non-null  object
#  1   title           206758 non-null  object
#  2   section         193277 non-null  object
#  3   author          184981 non-null  object
#  4   published_iso   206484 non-null  object
#  5   published_text  206737 non-null  object
#  6   tags            206762 non-null  object
#  7   body            189076 non-null  object
#  8   word_count      10146 non-null   float64
# dtypes: float64(1), object(8)
# memory usage: 14.2+ MB
# None
#
# --- SAMPLE ROWS ---
#                                                               url  \
# 141737       https://www.prothomalo.com/sports/cricket/2hug13aa9g
# 144657  https://www.prothomalo.com/bangladesh/district/fy74i787z8
# 49512    https://www.prothomalo.com/entertainment/song/3hu6slbgnr
# 185452      https://www.prothomalo.com/sports/football/fce6irgz9c
# 156763           https://www.prothomalo.com/bangladesh/as2934quji
#
#                                                                                                title  \
# 141737                                                                কেন সব স্মারক বেচে দিলেন বোথাম
# 144657                         দুই দিন বন্ধ থাকার পর হিলি স্থলবন্দর দিয়ে কাঁচা মরিচ এল ২৯ মেট্রিক টন
# 49512                                                           ১৭ বছরেও সঞ্জীবের গানের রং ফিকে হয়নি
# 185452                                                       বিশ্বকাপের শিরোপা আর্জেন্টিনারই প্রাপ্য
# 156763  ঘূর্ণিঝড়ের সতর্কতা নিয়ে উপহাস করা বোকামি, বললেন ১৯৯১ সালের ঘূর্ণিঝড়ে বেঁচে যাওয়া চন্দ্র নাথ
#
#          section                       author              published_iso  \
# 141737   ক্রিকেট                   খেলা ডেস্ক  2023-07-18T10:54:18+06:00
# 144657      জেলা                    প্রতিনিধি  2023-07-05T18:13:59+06:00
# 49512        গান           সৌমেন্দ্র গোস্বামী  2024-11-19T21:30:00+06:00
# 185452     ফুটবল  গোলাম সারোয়ার, গোললাইন থেকে  2022-12-19T15:00:00+06:00
# 156763  বাংলাদেশ               মানসুরা হোসাইন  2023-05-16T17:54:30+06:00
#
#                           published_text  \
# 141737      আপডেট: ১৮ জুলাই ২০২৩, ০৪: ৫৪
# 144657      আপডেট: ০৫ জুলাই ২০২৩, ১২: ১৩
# 49512    প্রকাশ: ১৯ নভেম্বর ২০২৪, ১৫: ৩০
# 185452  প্রকাশ: ১৯ ডিসেম্বর ২০২২, ০৯: ০০
# 156763         আপডেট: ১৬ মে ২০২৩, ১১: ৫৪
#
#                                                                                                           tags  \
# 141737                  [টেস্ট ক্রিকেট, আন্তর্জাতিক ক্রিকেট, ইয়ান বোথাম, অ্যাশেজ, ইংল্যান্ড ক্রিকেট দল, নিলাম]
# 144657                                                [রংপুর বিভাগ, হাকিমপুর, দিনাজপুর, কৃষি পণ্য, কাঁচা মরিচ]
# 49512                                                                           [স্মরণ, বাপ্পা মজুমদার, তারকা]
# 185452  [বিশ্বকাপ ফুটবল, কাতার বিশ্বকাপ, মেসি, আর্জেন্টিনা ফুটবল দল, কাতার বিশ্বকাপ ২০২২, বিশ্বকাপ ফুটবল ২০২২]
# 156763      [ঝড়, বিশেষ সংবাদ, ঘূর্ণিঝড়, প্রাকৃতিক দুর্যোগ, দুর্যোগ, চট্টগ্রাম, ঘূর্ণিঝড় মোখা, চট্টগ্রাম বিভাগ]
#
#                                                                                                                                                                                        body  \
# 141737  গত মাসেই জানা গিয়েছিল ক্যারিয়ারে অর্জিত অনেক পুরস্কার ও স্মারক বেচে দেবেন স্যার ইয়ান বোথাম। কাল সংবাদ সংস্থা এএফপি জানিয়েছে, লন্ডনে সারের হোমগ্রাউন্ড ওভালের লং রুমে আয়োজিত নিলা...
# 144657  লোকসানের অজুহাত দেখিয়ে দিনাজপুরের হিলি স্থলবন্দর দিয়ে ভারত থেকে দুদিন কাঁচা মরিচ আমদানি বন্ধ রাখার পর আজ বুধবার থেকে আবারও আমদানি শুরু করেছে তিনটি আমদানিকারক প্রতিষ্ঠান। এসব কা...
# 49512   লেখাপড়ায় অসাধারণ ছিলেন সঞ্জীব চৌধুরী। মাধ্যমিক ও উচ্চমাধ্যমিক—দুটি পরীক্ষাতেই মেধাতালিকায় স্থান করে নিয়েছিলেন। তারপর ঢাকা বিশ্ববিদ্যালয়ের গণিত বিভাগে ভর্তি হন; কিন্তু ভালো লাগল...
# 185452  তীব্র স্নায়ুর পরীক্ষা দিয়ে ফাইনালের মতো এক ফাইনালই দেখেছে গোটা বিশ্ব। শেষ পর্যন্ত শ্রেয়তর দলের হাতেই উঠেছে বিশ্বকাপের শিরোপা। অভিনন্দন আর্জেন্টিনা। এই শিরোপা তাদের প্রাপ্যই।\n\...
# 156763  চন্দ্র নাথ তখন কিশোর। সপ্তম শ্রেণিতে পড়েন। ১৯৯১ সালের কথা। সে বছর ভয়াবহ এক ঘূর্ণিঝড় আঘাত হেনেছিল চট্টগ্রামে, মারা গিয়েছিল ১ লাখ ৩৮ হাজার মানুষ। চোখের সামনে নিজের পরিবারকে সর্ব...
#
#         word_count
# 141737         NaN
# 144657         NaN
# 49512          NaN
# 185452         NaN
# 156763         NaN
#
# --- MISSING VALUES PER COLUMN ---
# url                    0
# title                  4
# section            13485
# author             21781
# published_iso        278
# published_text        25
# tags                   0
# body               17686
# word_count        196616
# dtype: int64
#
# --- DUPLICATE URL COUNT --- 142
#
# --- DATE RANGE ---
# 2016-02-01 01:12:22+06:00 to 2025-08-12 11:17:03+06:00
#
# --- ARTICLES PER YEAR ---
# published_dt
# 2016.0        1
# 2022.0    23311
# 2023.0    75614
# 2024.0    67795
# 2025.0    39763
# Name: count, dtype: int64
#
# --- TOP SECTIONS ---
# section
# জেলা            43093
# বাংলাদেশ        25603
# ক্রিকেট         10443
# ফুটবল            7711
# রাজনীতি          7469
# রাজধানী          5642
# কলাম             5203
# পড়াশোনা          4959
# নিয়োগ            3680
# বলিউড            3333
# ভারত             3185
# ইউরোপ            3180
# যুক্তরাষ্ট্র     3075
# বাণিজ্য          3028
# জীবনযাপন         2944
# মধ্যপ্রাচ্য      2821
# প্রযুক্তি        2704
# একটু থামুন       2570
# ইসলাম            2393
# সুস্থতা          2329
# Name: count, dtype: int64
#
# --- TOP AUTHORS ---
# author
# নিজস্ব প্রতিবেদক         43151
# প্রতিনিধি                26979
# খেলা ডেস্ক               14270
# প্রথম আলো ডেস্ক           8240
# বিনোদন ডেস্ক              4356
# ক্রীড়া প্রতিবেদক          3972
# বিশেষ প্রতিনিধি           3402
# বিনোদন প্রতিবেদক          3371
# এএফপি                     2871
# প্রযুক্তি ডেস্ক           2859
# বিশেষ প্রতিবেদক           2689
# বাণিজ্য ডেস্ক             2636
# রয়টার্স                   2498
# বিবিসি                    2307
# সংবাদদাতা                 1904
# বাসস                      1550
# প্রতিবেদক                 1482
# ফেরদৌস ফয়সাল              1451
# চাকরি-বাকরি প্রতিবেদক     1393
# আল জাজিরা                 1266
# Name: count, dtype: int64
#
# --- WORD COUNT STATS ---
# count    10146.000000
# mean       376.120540
# std        347.148499
# min          0.000000
# 25%        186.000000
# 50%        301.000000
# 75%        481.000000
# max       5006.000000
# Name: word_count, dtype: float64
#
# --- TOP LONGEST ARTICLES ---
#                                                         url  \
# 4248  https://www.prothomalo.com/onnoalo/stories/io7wdxbazf
# 7138  https://www.prothomalo.com/onnoalo/stories/c5fzbgm92l
# 1900       https://www.prothomalo.com/bangladesh/qjml02n1a5
# 1689         https://www.prothomalo.com/politics/eqn8xed646
# 5393       https://www.prothomalo.com/bangladesh/jvs3iaqxtq
#
#                                                        title  word_count
# 4248                                          আমি এইখানে নাই      5006.0
# 7138                                       দূরদেশ অথবা বনসাই      4799.0
# 1900                 আব্বা নায়ক হতে চেয়েছিলেন: ফেরদৌসী রহমান      4559.0
# 1689    এনসিপির ‘দ্বিতীয় রিপাবলিক’–এর ২৪ দফা ইশতেহারে যা আছে      4250.0
# 5393  এত বিস্ময়কর, এত স্বপ্নে ভরা পৃথিবী! এখানে আমি জন্মেছি      4091.0
#
# --- TOP TAGS ---
# চট্টগ্রাম বিভাগ    9788
# ঢাকা বিভাগ         8766
# রাজনীতি            8535
# বিএনপি             8031
# যুক্তরাষ্ট্র       6675
# শিক্ষা             6125
# রাজশাহী বিভাগ      6113
# আওয়ামী লীগ         6072
# রাজধানী ঢাকা       6024
# চট্টগ্রাম          5852
# অপরাধ              5492
# নির্বাচন           5437
# ভারত               5227
# চাকরিবাকরি         5187
# তারকা              5143
# ক্যারিয়ার          5104
# মামলা              5029
# খুলনা বিভাগ        5007
# পুলিশ              4742
# বিশেষ সংবাদ        4731
# Name: count, dtype: int64
#
# Total unique tags: 7610
#
# --- ARTICLES PER MONTH ---
# published_dt
# 2016-02       1
# 2022-07    2768
# 2022-08    4803
# 2022-09    4679
# 2022-10    5216
# 2022-11    1196
# 2022-12    4649
# 2023-01    5817
# 2023-02    6003
# 2023-03    7799
# 2023-04    4880
# 2023-05    5775
# 2023-06    7306
# 2023-07    7367
# 2023-08    7457
# 2023-09    6822
# 2023-10    7155
# 2023-11    4350
# 2023-12    4883
# 2024-01    6071
# 2024-02    6697
# 2024-03    7165
# 2024-04    6861
# 2024-05    4780
# 2024-06    5587
# 2024-07    1769
# 2024-08    7106
# 2024-09     239
# 2024-10    7349
# 2024-11    7035
# 2024-12    7136
# 2025-01    7358
# 2025-02    6751
# 2025-03    7639
# 2025-04    7231
# 2025-05      41
# 2025-06     580
# 2025-07    7275
# 2025-08    2888
# Freq: M, dtype: int64
# C:\Users\Saif\AppData\Local\Temp\ipykernel_2912\2768207708.py:65: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   print(df.groupby(df["published_dt"].dt.to_period("M")).size().sort_index())
